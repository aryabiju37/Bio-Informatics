# %% [markdown]
# <a href="https://colab.research.google.com/github/aryabiju37/Bio-Informatics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
#load in the data

mnist = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test = x_train / 255.0, x_test / 255.0
print("x_train.shape",x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train.shape (60000, 28, 28)

# %%
#Build the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation="relu"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10,activation="softmax")
])

# %%
#compile the model
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
#Train the model
r = model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2986 - accuracy: 0.9133 - val_loss: 0.1407 - val_accuracy: 0.9577
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1420 - accuracy: 0.9572 - val_loss: 0.1026 - val_accuracy: 0.9703
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1072 - accuracy: 0.9675 - val_loss: 0.0851 - val_accuracy: 0.9746
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0877 - accuracy: 0.9731 - val_loss: 0.0738 - val_accuracy: 0.9773
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0748 - accuracy: 0.9761 - val_loss: 0.0797 - val_accuracy: 0.9743
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0646 - accuracy: 0.9787 - val_loss: 0.0730 - val_accuracy: 0.9778
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0588 - accuracy: 0.9815 - val_loss: 0.0758 - val_accuracy: 0.9782
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0534 - accuracy: 0.9822 - val_loss: 0.0697 - val_accuracy: 0.9786
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0488 - accuracy: 0.9843 - val_loss: 0.0683 - val_accuracy: 0.9802
# Epoch 10/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0460 - accuracy: 0.9848 - val_loss: 0.0660 - val_accuracy: 0.9799

# %%
#plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'],label='acc')
plt.plot(r.history['val_accuracy'],label='val_acc')
plt.legend()

# %%
print(model.evaluate(x_test,y_test))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0660 - accuracy: 0.9799
# [0.065970279276371, 0.9799000024795532]
